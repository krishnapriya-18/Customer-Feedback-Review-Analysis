# %%
import re    # for regular expressions 
import nltk  # for text manipulation 
import string 
import warnings 
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt  
from wordcloud import WordCloud # data visualization library
#text features can be constructed using assorted techniques – Bag of Words, TF-IDF, and Word Embeddings.
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer #tfidf and Bag-of-Words Features.
import gensim # library for word2vec
# %matplotlib inline
pd.set_option("display.max_colwidth", 200) 
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
pos_rev = pd.read_csv('positive_reviews.csv')
neg_rev = pd.read_csv('negative_reviews.csv')

# %%
pos_rev.head()
# Out:
#                                                                                                                                                                                                       text  \
# 0                                         These stickers work like the review says they do. They stick on great and they stay on the phone. They are super stylish and I can share them with my sister. :)
# 1                                   These are awesome and make my phone look so stylish! I have only used one so far and have had it on for almost a year! CAN YOU BELIEVE THAT! ONE YEAR!! Great quality!
# 2                                                                  awesome! stays on, and looks great. can be used on multiple apple products.  especially having nails, it helps to have an elevated key.
# ...

# %%
neg_rev.head()
# Out:
#                                                                                                                                                                                                       text  \
# 0                                                                                                                it worked for the first week then it only charge my phone to 20%. it is a waste of money.
# 1                                                                                     It worked great for the first couple of weeks then it just stopped completely.. so basically a small waste of money.
# 2       Only works one side at a time. When you connect two cables, one side stop working and also overheated burning the fuses. I purchased two of them and it's the same problem. Cheap and bad quality.
# ...

# %%
pos_rev['reviews'] = pos_rev.text + pos_rev.summary

# %%
neg_rev['reviews'] = neg_rev.text + neg_rev.summary

# %%
pos_rev.head()
# Out:
#                                                                                                                                                                                                       text  \
# 0                                         These stickers work like the review says they do. They stick on great and they stay on the phone. They are super stylish and I can share them with my sister. :)
# 1                                   These are awesome and make my phone look so stylish! I have only used one so far and have had it on for almost a year! CAN YOU BELIEVE THAT! ONE YEAR!! Great quality!
# 2                                                                  awesome! stays on, and looks great. can be used on multiple apple products.  especially having nails, it helps to have an elevated key.
# ...

# %%
pos_rev1 = pd.DataFrame(pos_rev).drop(['text', 'summary'], axis=1)
neg_rev1 = pd.DataFrame(neg_rev).drop(['text', 'summary'], axis=1)

# %%
pos_rev.head()
# Out:
#                                                                                                                                                                                                       text  \
# 0                                         These stickers work like the review says they do. They stick on great and they stay on the phone. They are super stylish and I can share them with my sister. :)
# 1                                   These are awesome and make my phone look so stylish! I have only used one so far and have had it on for almost a year! CAN YOU BELIEVE THAT! ONE YEAR!! Great quality!
# 2                                                                  awesome! stays on, and looks great. can be used on multiple apple products.  especially having nails, it helps to have an elevated key.
# ...

# %%
pos_rev1.head()
# Out:
#    rating  \
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#
#                                                                                                                                                                                                    reviews
# 0                    These stickers work like the review says they do. They stick on great and they stay on the phone. They are super stylish and I can share them with my sister. :)Really great product.
# 1                     These are awesome and make my phone look so stylish! I have only used one so far and have had it on for almost a year! CAN YOU BELIEVE THAT! ONE YEAR!! Great quality!LOVE LOVE LOVE
# 2                         awesome! stays on, and looks great. can be used on multiple apple products.  especially having nails, it helps to have an elevated key.leopard home button sticker for iphone 4s
# ...

# %%
neg_rev1.head()
# Out:
#    rating  \
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#
#                                                                                                                                                                                                    reviews
# 0                                                                                                 it worked for the first week then it only charge my phone to 20%. it is a waste of money.not a good Idea
# 1                                                                             It worked great for the first couple of weeks then it just stopped completely.. so basically a small waste of money.Horrible
# 2  Only works one side at a time. When you connect two cables, one side stop working and also overheated burning the fuses. I purchased two of them and it's the same problem. Cheap and bad quality.do...
# ...

# %%
pos_rev1_set = pos_rev1.iloc[:10000,:]
neg_rev1_set = neg_rev1.iloc[:5000,:]

train1 = pd.concat([pos_rev1_set, neg_rev1_set], axis=0, ignore_index=True)
train1.rename(columns = {'rating':'label'}, inplace = True)

# %%
train1.shape
# Out:
# (15000, 2)

# %%
train1.head()
# Out:
#    label  \
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#
#                                                                                                                                                                                                    reviews
# 0                    These stickers work like the review says they do. They stick on great and they stay on the phone. They are super stylish and I can share them with my sister. :)Really great product.
# 1                     These are awesome and make my phone look so stylish! I have only used one so far and have had it on for almost a year! CAN YOU BELIEVE THAT! ONE YEAR!! Great quality!LOVE LOVE LOVE
# 2                         awesome! stays on, and looks great. can be used on multiple apple products.  especially having nails, it helps to have an elevated key.leopard home button sticker for iphone 4s
# ...

# %%
train1['label'].value_counts()
# Out:
# 5    10000
# 1     5000
# Name: label, dtype: int64

# %%
train1.to_csv('train_subset.csv', index=False)

# %%
train = pd.concat([pos_rev1, neg_rev1], axis=0, ignore_index=True)

# %%
train.head()
# Out:
#    rating  \
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#
#                                                                                                                                                                                                    reviews
# 0                    These stickers work like the review says they do. They stick on great and they stay on the phone. They are super stylish and I can share them with my sister. :)Really great product.
# 1                     These are awesome and make my phone look so stylish! I have only used one so far and have had it on for almost a year! CAN YOU BELIEVE THAT! ONE YEAR!! Great quality!LOVE LOVE LOVE
# 2                         awesome! stays on, and looks great. can be used on multiple apple products.  especially having nails, it helps to have an elevated key.leopard home button sticker for iphone 4s
# ...

# %%
train.rename(columns = {'rating':'label'}, inplace = True)

# %%
train.head()
# Out:
#    label  \
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#
#                                                                                                                                                                                                    reviews
# 0                    These stickers work like the review says they do. They stick on great and they stay on the phone. They are super stylish and I can share them with my sister. :)Really great product.
# 1                     These are awesome and make my phone look so stylish! I have only used one so far and have had it on for almost a year! CAN YOU BELIEVE THAT! ONE YEAR!! Great quality!LOVE LOVE LOVE
# 2                         awesome! stays on, and looks great. can be used on multiple apple products.  especially having nails, it helps to have an elevated key.leopard home button sticker for iphone 4s
# ...

# %%
train.to_csv('train.csv', index=False)

# %%
test1 = pd.read_csv('Happay Enterprise_reviews.csv')

# %%
test1.head()
# Out:
#         reviewer_name                           rating        review_date  \
# 0    dipakkumar nayak  Rated 4 stars out of five stars        May 5  2019
# 1     Nishant Mamoria  Rated 1 stars out of five stars     March 13  2019
# 2  Mustafa kiranawala  Rated 5 stars out of five stars  February 27  2019
# 3     rakesh chakilam  Rated 2 stars out of five stars     March 17  2019
# 4      SATHIYARAJAN p  Rated 5 stars out of five stars     April 20  2019
#
#     upvote  \
# 0      0.0
# 1      0.0
# 2      2.0
# 3      1.0
# 4      2.0
#
#                                                                                                                                                                                                     review
# 0               sometimes it don't work properly. ex : it shows the input amount twice in a monthly budget while I have inputed once & sometimes the selected expenses were not in the final expense sheet
# ...

# %%
test1.columns = test1.columns.str.strip()
test1.rating = test1.rating.str.replace("[^0-9]"," ")

# %%
test1.head()
# Out:
#         reviewer_name                           rating        review_date  \
# 0    dipakkumar nayak        4                                May 5  2019
# 1     Nishant Mamoria        1                             March 13  2019
# 2  Mustafa kiranawala        5                          February 27  2019
# 3     rakesh chakilam        2                             March 17  2019
# 4      SATHIYARAJAN p        5                             April 20  2019
#
#    upvote  \
# 0     0.0
# 1     0.0
# 2     2.0
# 3     1.0
# 4     2.0
#
#                                                                                                                                                                                                     review
# 0               sometimes it don't work properly. ex : it shows the input amount twice in a monthly budget while I have inputed once & sometimes the selected expenses were not in the final expense sheet
# ...

# %%
test1 = test1.rename(columns={'review': 'reviews'})

# %%
test1.head()
# Out:
#         reviewer_name                           rating        review_date  \
# 0    dipakkumar nayak        4                                May 5  2019
# 1     Nishant Mamoria        1                             March 13  2019
# 2  Mustafa kiranawala        5                          February 27  2019
# 3     rakesh chakilam        2                             March 17  2019
# 4      SATHIYARAJAN p        5                             April 20  2019
#
#    upvote  \
# 0     0.0
# 1     0.0
# 2     2.0
# 3     1.0
# 4     2.0
#
#                                                                                                                                                                                                    reviews
# 0               sometimes it don't work properly. ex : it shows the input amount twice in a monthly budget while I have inputed once & sometimes the selected expenses were not in the final expense sheet
# ...

# %%
test1.to_csv('Happay_enterprise_reviews_test.csv', index=False)
